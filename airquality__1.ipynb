# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from scipy.io import loadmat
import seaborn as sn
import datetime

# %%
df = pd.read_csv("E:/DATA_ML/Kaggle Air pollution/air_pollu.csv", encoding='cp1252')

# %%
df
# Out:
#        stn_code sampling_date   state location  \
# 0          29.0    10-03-1987  Kerala    Kochi
# 1          30.0    04-05-1988  Kerala    Kochi
# 2          31.0    04-05-1988  Kerala    Kochi
# 3          32.0    04-05-1988  Kerala    Kochi
# 4          33.0    04-05-1988  Kerala    Kochi
# ...         ...           ...     ...      ...
# 24723     624.0    16-12-2015  Kerala  Thissur
# 24724     624.0    18-12-2015  Kerala  Thissur
# 24725     624.0    21-12-2015  Kerala  Thissur
# 24726     624.0    28-12-2015  Kerala  Thissur
# 24727     624.0    30-12-2015  Kerala  Thissur
#
#                                      agency             type  so2   no2  rspm  \
# 0            Kerala Pollution Control Board      Residential  NaN   2.9   NaN
# 1            Kerala Pollution Control Board  Industrial Area  NaN   NaN   NaN
# 2            Kerala Pollution Control Board  Industrial Area  NaN   NaN   NaN
# 3            Kerala Pollution Control Board  Industrial Area  NaN   NaN   NaN
# ...

# %%
df['Date']= pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24728 entries, 0 to 24727
# Data columns (total 14 columns):
# stn_code                       17866 non-null float64
# sampling_date                  24728 non-null object
# state                          24728 non-null object
# location                       24728 non-null object
# agency                         17432 non-null object
# type                           24728 non-null object
# so2                            22394 non-null float64
# no2                            23359 non-null float64
# rspm                           22682 non-null float64
# spm                            10555 non-null float64
# location_monitoring_station    22695 non-null object
# pm2_5                          0 non-null float64
# date                           24728 non-null object
# Date                           24728 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 2.6+ MB

# %%
df.isnull().sum()
# Out:
# stn_code                        6862
# sampling_date                      0
# state                              0
# location                           0
# agency                          7296
# type                               0
# so2                             2334
# no2                             1369
# rspm                            2046
# spm                            14173
# location_monitoring_station     2033
# pm2_5                          24728
# date                               0
# Date                               0
# dtype: int64

# %%
df=df.drop(['agency','state','stn_code','sampling_date','location_monitoring_station','pm2_5','spm'],axis=1)

# %%
df
# Out:
#       location             type  so2   no2  rspm        date       Date
# 0        Kochi      Residential  NaN   2.9   NaN  10-03-1987 1987-10-03
# 1        Kochi  Industrial Area  NaN   NaN   NaN  04-05-1988 1988-04-05
# 2        Kochi  Industrial Area  NaN   NaN   NaN  04-05-1988 1988-04-05
# 3        Kochi  Industrial Area  NaN   NaN   NaN  04-05-1988 1988-04-05
# 4        Kochi            Other  NaN   NaN   NaN  04-05-1988 1988-04-05
# ...        ...              ...  ...   ...   ...         ...        ...
# 24723  Thissur      Residential  2.0   5.0  64.0  16-12-2015 2015-12-16
# 24724  Thissur      Residential  2.0  15.0  43.0  18-12-2015 2015-12-18
# 24725  Thissur      Residential  2.0   5.0  60.0  21-12-2015 2015-12-21
# 24726  Thissur      Residential  2.0   5.0  61.0  28-12-2015 2015-12-28
# 24727  Thissur      Residential  2.0   5.0  59.0  30-12-2015 2015-12-30
#
# [24728 rows x 7 columns]

# %%
plt.bar(df['type'].unique(), df['type'].value_counts(), color ='blue',  
        width = 0.4)
# Out:
# <BarContainer object of 3 artists>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24728 entries, 0 to 24727
# Data columns (total 7 columns):
# location    24728 non-null object
# type        24728 non-null object
# so2         22394 non-null float64
# no2         23359 non-null float64
# rspm        22682 non-null float64
# date        24728 non-null object
# Date        24728 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# location       0
# type           0
# so2         2334
# no2         1369
# rspm        2046
# date           0
# Date           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['location', 'type', 'so2', 'no2', 'rspm', 'date', 'Date'], dtype='object')

# %%
df['so2'].fillna(method='pad', inplace=True)
df['no2'].fillna(method='pad', inplace=True)
df['rspm'].fillna(method='pad', inplace=True)

# %%
df.isnull().sum()
# Out:
# location       0
# type           0
# so2           37
# no2            0
# rspm        2033
# date           0
# Date           0
# dtype: int64

# %%
df['so2'].head(40)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    4.6
# 38    4.2
# 39    4.3
# Name: so2, dtype: float64

# %%
df['so2'].fillna(4.6, inplace=True)

# %%
df['rspm'].fillna(df.rspm.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# location    0
# type        0
# so2         0
# no2         0
# rspm        0
# date        0
# Date        0
# year        0
# dtype: int64

# %%
df['year'] = pd.DatetimeIndex(df['Date']).year

# %%
df.head()
# Out:
#   location             type  so2  no2       rspm        date       Date  year
# 0    Kochi      Residential  4.6  2.9  50.631866  10-03-1987 1987-10-03  1987
# 1    Kochi  Industrial Area  4.6  2.9  50.631866  04-05-1988 1988-04-05  1988
# 2    Kochi  Industrial Area  4.6  2.9  50.631866  04-05-1988 1988-04-05  1988
# 3    Kochi  Industrial Area  4.6  2.9  50.631866  04-05-1988 1988-04-05  1988
# 4    Kochi            Other  4.6  2.9  50.631866  04-05-1988 1988-04-05  1988

# %%
fig, ax = plt.subplots(figsize=(10, 6))
# make barplot
ax.bar(df['location'],df['so2'])
# set labels
ax.set(xlabel = "location",ylabel = "so2")
plt.setp(ax.get_xticklabels(),rotation = 50)
plt.title("so2 concentrations", size=18)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(df['location'],df['no2'])  
# set labels
ax.set(xlabel = "location",ylabel = "no2")
plt.setp(ax.get_xticklabels(),rotation = 50)
plt.title("no2 concentrations", size=18)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(df['location'],df['rspm']) 
# set labels
ax.set(xlabel = "location",ylabel = "rspm")
plt.setp(ax.get_xticklabels(),rotation = 50)
plt.title("rspm concentrations", size=18)
plt.tight_layout()

# %%
#Scatter plots of all columns
cols = ['so2', 'no2', 'rspm']
sn.pairplot(df[cols], size = 2.5)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
corrMatrix = df.corr()
f, ax = plt.subplots(figsize = (15, 10))
sn.heatmap(corrMatrix, vmax = 1, square = True,annot=True)
plt.show()

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df.head()
# Out:
#   location             type  so2  no2       rspm        date       Date  year
# 0    Kochi      Residential  4.6  2.9  50.631866  10-03-1987 1987-10-03  1987
# 1    Kochi  Industrial Area  4.6  2.9  50.631866  04-05-1988 1988-04-05  1988
# 2    Kochi  Industrial Area  4.6  2.9  50.631866  04-05-1988 1988-04-05  1988
# 3    Kochi  Industrial Area  4.6  2.9  50.631866  04-05-1988 1988-04-05  1988
# 4    Kochi            Other  4.6  2.9  50.631866  04-05-1988 1988-04-05  1988

# %%
df = df.drop(['Date'],axis=1)
df
# Out:
#       location             type  so2   no2       rspm        date  year
# 0        Kochi      Residential  4.6   2.9  50.631866  10-03-1987  1987
# 1        Kochi  Industrial Area  4.6   2.9  50.631866  04-05-1988  1988
# 2        Kochi  Industrial Area  4.6   2.9  50.631866  04-05-1988  1988
# 3        Kochi  Industrial Area  4.6   2.9  50.631866  04-05-1988  1988
# 4        Kochi            Other  4.6   2.9  50.631866  04-05-1988  1988
# ...        ...              ...  ...   ...        ...         ...   ...
# 24723  Thissur      Residential  2.0   5.0  64.000000  16-12-2015  2015
# 24724  Thissur      Residential  2.0  15.0  43.000000  18-12-2015  2015
# 24725  Thissur      Residential  2.0   5.0  60.000000  21-12-2015  2015
# 24726  Thissur      Residential  2.0   5.0  61.000000  28-12-2015  2015
# 24727  Thissur      Residential  2.0   5.0  59.000000  30-12-2015  2015
#
# [24728 rows x 7 columns]

# %%
# Heatmap Pivot with State as Row, Year as Col, No2 as Value
f, ax = plt.subplots(figsize = (10,10))
ax.set_title('{} by location and year'.format('so2'))
sn.heatmap(df.pivot_table('so2', index = 'location',
                columns = ['year'], aggfunc = 'median', margins=True),
                annot = True, cmap = 'YlGnBu', linewidths = 1, ax = ax, cbar_kws = {'label': 'Average taken Annually'})

# %%
# Heatmap Pivot with State as Row, Year as Col, So2 as Value
f, ax = plt.subplots(figsize=(10,10))
ax.set_title('{} by state and year'.format('no2'))
sn.heatmap(df.pivot_table('no2', index='location',
                columns=['year'],aggfunc='median',margins=True),
                annot = True, cmap = "YlGnBu", linewidths = 1, ax = ax,cbar_kws = {'label': 'Annual Average'})

# %%
# Heatmap Pivot with State as Row, Year as Col, So2 as Value
f, ax = plt.subplots(figsize=(10,10))
ax.set_title('{} by state and year'.format('rspm'))
sn.heatmap(df.pivot_table('rspm', index='location',
                columns=['year'],aggfunc='median',margins=True),
                annot = True, cmap = "YlGnBu", linewidths = 1, ax = ax,cbar_kws = {'label': 'Annual Average'})

# %% [markdown]
# ## Time Series Analysis

# %%
df_so2 = df[["date", "so2"]]
df_so2 = df_so2.dropna()

# %%
import dask.dataframe as dd

# %%
df_so2['date'] = pd.to_datetime(df_so2['date'])
df_so2.set_index(df_so2['date'],inplace=True)
df_so2.index
df_so21 = dd.from_pandas(df_so2, npartitions=1)
df_so21.index.head()
# Out:
# DatetimeIndex(['1987-10-03', '1988-04-05', '1988-04-05', '1988-04-05',
#                '1988-04-05'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
df_so2_resample = df_so2.resample(rule = "M").mean().ffill()

# %%
df_so2_resample.plot(figsize = (20,10))

# %%
df_so2_resample["so2"].resample("A").mean().plot.bar(figsize = (20,10))

# %%
df_so2_resample.plot(figsize = (20,10))
df_so2_resample.rolling(window = 7).mean()["so2"].plot(figsize = (20,10))

# %% [markdown]
# # Testing the stationarity

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(df_so2_resample["so2"])
print('Augmented Dickey-Fuller Test:')
labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']

for value,label in zip(result,labels):
    print(label+' : '+str(value) )
    
if result[1] <= 0.05:
    print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
else:
    print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -1.6787045372588052
# p-value : 0.4421165847158838
# #Lags Used : 2
# Number of Observations Used : 336
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
df_so2_resample["so2_first_diff"] = df_so2_resample["so2"] - df_so2_resample["so2"].shift(7)
# CHECK
result = adfuller(df_so2_resample["so2_first_diff"].dropna() )
print('Augmented Dickey-Fuller Test:')
labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']

for value,label in zip(result,labels):
    print(label+' : '+str(value) )
    
if result[1] <= 0.05:
    print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
else:
    print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")
# Out:
# Augmented Dickey-Fuller Test:
# ADF Test Statistic : -3.805569707857871
# p-value : 0.0028508409058650612
# #Lags Used : 15
# Number of Observations Used : 316
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
df_so2_resample["so2_first_diff"].plot(figsize = (20,10))

# %%
df_so2_resample["so2_second_diff"] = df_so2_resample["so2_first_diff"] - df_so2_resample["so2_first_diff"].shift(7)
df_so2_resample["so2_second_diff"].plot(figsize = (20,10))

# %%
import statsmodels.api as sm

model = sm.tsa.statespace.SARIMAX(df_so2_resample["so2"],order=(0,1,0), seasonal_order=(1,1,1,48))
results = model.fit()
print(results.summary())
results.resid.plot()
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                                so2   No. Observations:                  339
# Model:             SARIMAX(0, 1, 0)x(1, 1, 1, 48)   Log Likelihood                -440.432
# Date:                            Sat, 19 Dec 2020   AIC                            886.864
# Time:                                    14:48:51   BIC                            897.874
# Sample:                                10-31-1987   HQIC                           891.275
#                                      - 12-31-2015
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L48      -0.0355      0.066     -0.535      0.592      -0.165       0.094
# ma.S.L48      -0.9984     14.844     -0.067      0.946     -30.092      28.095
# ...

# %%
results.resid.plot(kind='kde')

# %%
#check with known data
df_so2_resample['forecast'] = results.predict(start = 250, end= 400, dynamic= True)  
df_so2_resample[['so2','forecast']].plot(figsize=(20,10))

# %% [markdown]
# ## Forecast

# %%
from pandas.tseries.offsets import DateOffset
future_dates = [df_so2_resample.index[-1] + DateOffset(months=x) for x in range(0,24) ]
future_dates_df = pd.DataFrame(index=future_dates[1:],columns=df_so2_resample.columns)
future_df = pd.concat([df_so2_resample,future_dates_df])
future_df['forecast2'] = results.predict(start = 348, end = 540, dynamic= True)  
future_df[['so2', 'forecast2']].plot(figsize=(20, 10))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py:1960: ValueWarning: Dynamic prediction specified to begin during out-of-sample forecasting period, and so has no effect.
#   ' effect.', ValueWarning)
